# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

bhv_1=pd.read_csv(r'C:\Program Files (x86)\Umram\ActionClusters Project\ActionClusters(mixed)\Experiment_Folder\Output\Umur\bhvratings101_1.csv')
pairs_1=pd.read_csv(r'C:\Program Files (x86)\Umram\ActionClusters Project\ActionClusters(mixed)\Experiment_Folder\Output\Umur\sespairs101_1.csv')
bhv_2=pd.read_csv(r'C:\Program Files (x86)\Umram\ActionClusters Project\ActionClusters(mixed)\Experiment_Folder\Output\Umur\bhvratings101_2.csv')
pairs_2=pd.read_csv(r'C:\Program Files (x86)\Umram\ActionClusters Project\ActionClusters(mixed)\Experiment_Folder\Output\Umur\sespairs101_2.csv')

bhv_3=pd.read_csv(r'C:\Program Files (x86)\Umram\ActionClusters Project\ActionClusters(mixed)\Experiment_Folder\Output\Umur\bhvratings101_3.csv')

pairs_3=pd.read_csv(r'C:\Program Files (x86)\Umram\ActionClusters Project\ActionClusters(mixed)\Experiment_Folder\Output\Umur\sespairs101_3.csv')

# %%
pd.set_option('display.max_colwidth', None)
display(pairs_3)
# Out:
#                                                                                    mov1  \
# 0    C:\Users\VPL_User2\Documents\CCNLab\ActionClusters\OriginalVideos\Videos\089_F.avi
# 1    C:\Users\VPL_User2\Documents\CCNLab\ActionClusters\OriginalVideos\Videos\074_F.avi
# 2    C:\Users\VPL_User2\Documents\CCNLab\ActionClusters\OriginalVideos\Videos\075_F.avi
# 3    C:\Users\VPL_User2\Documents\CCNLab\ActionClusters\OriginalVideos\Videos\050_M.avi
# 4    C:\Users\VPL_User2\Documents\CCNLab\ActionClusters\OriginalVideos\Videos\053_M.avi
# ..                                                                                  ...
# 546  C:\Users\VPL_User2\Documents\CCNLab\ActionClusters\OriginalVideos\Videos\099_F.avi
# 547  C:\Users\VPL_User2\Documents\CCNLab\ActionClusters\OriginalVideos\Videos\062_M.avi
# 548  C:\Users\VPL_User2\Documents\CCNLab\ActionClusters\OriginalVideos\Videos\068_M.avi
# 549  C:\Users\VPL_User2\Documents\CCNLab\ActionClusters\OriginalVideos\Videos\078_F.avi
# ...

# %%
merged_ratings = pd.concat([bhv_1, bhv_2, bhv_3], axis=0, ignore_index=True)
merged_pairs = pd.concat([pairs_1, pairs_2, pairs_3], axis=0, ignore_index=True)

unique_values = merged_pairs['mov1'].unique()
print(unique_values)
# Out:
# ['C:\\Users\\VPL_User2\\Documents\\CCNLab\\ActionClusters\\OriginalVideos\\Videos\\075_F.avi'
#  'C:\\Users\\VPL_User2\\Documents\\CCNLab\\ActionClusters\\OriginalVideos\\Videos\\100_F.avi'
#  'C:\\Users\\VPL_User2\\Documents\\CCNLab\\ActionClusters\\OriginalVideos\\Videos\\099_F.avi'
#  'C:\\Users\\VPL_User2\\Documents\\CCNLab\\ActionClusters\\OriginalVideos\\Videos\\044_M.avi'
#  'C:\\Users\\VPL_User2\\Documents\\CCNLab\\ActionClusters\\OriginalVideos\\Videos\\058_M.avi'
#  'C:\\Users\\VPL_User2\\Documents\\CCNLab\\ActionClusters\\OriginalVideos\\Videos\\078_F.avi'
#  'C:\\Users\\VPL_User2\\Documents\\CCNLab\\ActionClusters\\OriginalVideos\\Videos\\077_F.avi'
#  'C:\\Users\\VPL_User2\\Documents\\CCNLab\\ActionClusters\\OriginalVideos\\Videos\\095_F.avi'
#  'C:\\Users\\VPL_User2\\Documents\\CCNLab\\ActionClusters\\OriginalVideos\\Videos\\082_F.avi'
#  'C:\\Users\\VPL_User2\\Documents\\CCNLab\\ActionClusters\\OriginalVideos\\Videos\\062_M.avi'
# ...

# %%
merged_pairs[merged_pairs['mov1'].str.contains('085')]
# Out:
#                                                                                     mov1  \
# 17    C:\Users\VPL_User2\Documents\CCNLab\ActionClusters\OriginalVideos\Videos\085_F.avi
# 23    C:\Users\VPL_User2\Documents\CCNLab\ActionClusters\OriginalVideos\Videos\085_F.avi
# 24    C:\Users\VPL_User2\Documents\CCNLab\ActionClusters\OriginalVideos\Videos\085_F.avi
# 55    C:\Users\VPL_User2\Documents\CCNLab\ActionClusters\OriginalVideos\Videos\085_F.avi
# 88    C:\Users\VPL_User2\Documents\CCNLab\ActionClusters\OriginalVideos\Videos\085_F.avi
# 124   C:\Users\VPL_User2\Documents\CCNLab\ActionClusters\OriginalVideos\Videos\085_F.avi
# 150   C:\Users\VPL_User2\Documents\CCNLab\ActionClusters\OriginalVideos\Videos\085_F.avi
# 203   C:\Users\VPL_User2\Documents\CCNLab\ActionClusters\OriginalVideos\Videos\085_F.avi
# 285   C:\Users\VPL_User2\Documents\CCNLab\ActionClusters\OriginalVideos\Videos\085_F.avi
# ...

# %%
merged_pairs['mov2'] = merged_pairs['mov2'].str.replace(r'^.*\\Videos', '')
merged_pairs['mov2'] = merged_pairs['mov2'].str.replace('.avi', '')
merged_pairs['mov2'] = merged_pairs['mov2'].str.replace('\\', '')
merged_pairs['mov1'] = merged_pairs['mov1'].str.replace(r'^.*\\Videos', '')
merged_pairs['mov1'] = merged_pairs['mov1'].str.replace('.avi', '')
merged_pairs['mov1'] = merged_pairs['mov1'].str.replace('\\', '')
# Out:
# C:\Users\UmurY\AppData\Local\Temp/ipykernel_23236/3628096116.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   merged_pairs['mov2'] = merged_pairs['mov2'].str.replace(r'^.*\\Videos', '')
# C:\Users\UmurY\AppData\Local\Temp/ipykernel_23236/3628096116.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   merged_pairs['mov2'] = merged_pairs['mov2'].str.replace('.avi', '')
# C:\Users\UmurY\AppData\Local\Temp/ipykernel_23236/3628096116.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   merged_pairs['mov2'] = merged_pairs['mov2'].str.replace('\\', '')
# C:\Users\UmurY\AppData\Local\Temp/ipykernel_23236/3628096116.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
# ...

# %%
merged_pairs
merged_pairs[((merged_pairs['mov1'].str.contains('017')) & (merged_pairs['mov2'].str.contains('075'))) |
                           ((merged_pairs['mov1'].str.contains('075')) & (merged_pairs['mov2'].str.contains('017')))]
# Out:
#       mov1   mov2
# 462  075_F  017_M

# %%
filtered_pairs = merged_ratings[
    (merged_pairs['mov1'].str.contains('085') & merged_pairs['mov2'].str.contains('082')) |
    (merged_pairs['mov1'].str.contains('082') & merged_pairs['mov2'].str.contains('085'))
]
filtered_pairs
# Out:
#     response        RT
# 473       1!  1.315571

# %%
#Pairs of Null responses
list_null = merged_ratings[merged_ratings['response'].isnull()]
merged_pairs[merged_pairs.index.isin(list_null.index)]
# Out:
#        mov1   mov2
# 27    068_M  051_F
# 115   012_M  005_F
# 259   098_F  057_M
# 264   100_F  023_M
# 457   096_F  012_M
# 591   071_M  062_F
# 702   087_F  077_M
# 962   100_F  087_M
# 1141  095_F  075_M
# 1250  087_F  072_M
# 1338  096_F  078_M
# 1575  015_M  002_F

# %%
merged_ratings['response'].fillna('3#', inplace=True)
merged_ratings[merged_ratings['response'].isnull()]
# Out:
# Empty DataFrame
# Columns: [response, RT]
# Index: []

# %%
print(merged_pairs['mov1'].unique())
print(merged_pairs['mov2'].unique())
# Out:
# ['075_F' '100_F' '099_F' '044_M' '058_M' '078_F' '077_F' '095_F' '082_F'
#  '062_M' '092_F' '064_M' '022_M' '085_F' '068_M' '098_F' '040_M' '074_F'
#  '094_F' '088_F' '096_F' '059_M' '055_M' '089_F' '063_M' '051_M' '072_F'
#  '035_M' '087_F' '048_M' '047_M' '071_M' '041_M' '070_M' '031_M' '042_M'
#  '020_M' '053_M' '024_M' '012_M' '046_M' '015_M' '049_M' '057_M' '023_M'
#  '072_M' '027_M' '036_M' '021_M' '050_M' '017_M' '028_M' '008_M' '013_M'
#  '016_M' '007_M' '004_M' '005_M']
# ['007_M' '047_M' '022_M' '036_F' '046_F' '017_M' '012_M' '021_M' '053_M'
#  '040_M' '023_F' '024_M' '059_F' '008_F' '049_M' '042_M' '002_F' '059_M'
#  '085_M' '005_M' '002_M' '022_F' '068_M' '051_F' '020_M' '051_M' '049_F'
#  '077_M' '013_F' '041_M' '004_F' '028_M' '004_M' '087_M' '036_M' '058_M'
#  '041_F' '007_F' '057_M' '023_M' '020_F' '055_M' '075_M' '063_F' '031_F'
#  '024_F' '048_M' '035_M' '050_M' '031_M' '040_F' '016_F' '021_F' '050_F'
# ...

# %%
merged_pairs['mov1'] = merged_pairs['mov1'].str.replace(r'[^0-9]', '', regex=True)
merged_pairs['mov2'] = merged_pairs['mov2'].str.replace(r'[^0-9]', '', regex=True)

# %%
merged_pairs[merged_ratings['response']=='space']
# Out:
#     mov1 mov2
# 19   098  059
# 166  064  028
# 476  096  005
# 979  088  070

# %%
merged_ratings['response'].unique()
merged_ratings[merged_ratings['response']=='space']='3#'

# %%
merged_ratings['response'] = merged_ratings['response'].str.replace(r'[^0-9]', '', regex=True).astype(int)
print(merged_ratings)


merged_ratings.iloc[3]+merged_ratings.iloc[4]
# Out:
#       response         RT
# 0            2  52.785678
# 1            4   72.83014
# 2            6  18.369398
# 3            3  15.182659
# 4            2  18.531935
# ...        ...        ...
# 1648         1  10.841287
# 1649         1   2.258966
# 1650         1   3.746646
# 1651         1    5.81782
# 1652         6   4.831059
#
# [1653 rows x 2 columns]
# response            5
# RT          33.714594
# dtype: object

# %%
merged_pairs['responses']=merged_ratings['response']

# %%
comm_vocal = [2, 28, 85, 95]
passive_inter = [4, 35, 58, 63, 89, 94]
manipulation = [7, 12, 13, 31, 50, 53, 96]
aim_in_space = [8, 20, 49, 71, 78, 87, 100]
skin_displacement = [15, 16, 23, 70]
digestion = [17, 21, 41, 72,88,92]
modify_substrate = [22, 44, 46, 64, 99]
active_inter = [36, 42, 47, 59, 75, 98]
comm_symbolic = [40, 51, 57]
locomotion_b = [55, 62, 68]
locomotion_q = [5,24,27,48,74, 77, 82]
list_order = [
    passive_inter, active_inter, comm_symbolic, comm_vocal,
    manipulation, modify_substrate, digestion,skin_displacement,
    aim_in_space, locomotion_b, locomotion_q
]
combined_lists = [num for sublist in list_order for num in sublist]
n = len(combined_lists)
df = pd.DataFrame(index=[f'A{num}' for num in combined_lists], columns=[f'A{num}' for num in combined_lists])
df.values[[range(n)], [range(n)]] = 7
print(df)
# Out:
#        A4  A35  A58  A63  A89  A94  A36  A42  A47  A59  ...  A55  A62  A68  \
# A4      7  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# A35   NaN    7  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# A58   NaN  NaN    7  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# A63   NaN  NaN  NaN    7  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# A89   NaN  NaN  NaN  NaN    7  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# A94   NaN  NaN  NaN  NaN  NaN    7  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# A36   NaN  NaN  NaN  NaN  NaN  NaN    7  NaN  NaN  NaN  ...  NaN  NaN  NaN
# A42   NaN  NaN  NaN  NaN  NaN  NaN  NaN    7  NaN  NaN  ...  NaN  NaN  NaN
# A47   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    7  NaN  ...  NaN  NaN  NaN
# A59   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    7  ...  NaN  NaN  NaN
# A75   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# ...

# %%
merged_pairs['mov1'] = merged_pairs['mov1'].str.replace(r'^0+', 'A', regex=True)
merged_pairs['mov2'] = merged_pairs['mov2'].str.replace(r'^0+', 'A', regex=True)
merged_pairs['mov1'] = merged_pairs['mov1'].str.replace(r'^0+', 'A', regex=True).replace('100', 'A100')
merged_pairs['mov2'] = merged_pairs['mov2'].str.replace(r'^0+', 'A', regex=True).replace('100', 'A100')

# %%
for row_idx, row in df.iterrows():
    for col_idx, value in row.iteritems():
        if pd.isnull(value):
            response_row = merged_pairs[((merged_pairs['mov1'] == row_idx) & (merged_pairs['mov2'] == col_idx)) | ((merged_pairs['mov1'] == col_idx) & (merged_pairs['mov2'] == row_idx))]
            if not response_row.empty:
                df.at[row_idx, col_idx] = response_row['responses'].values[0]

# %%
df
# Out:
#      A4 A35 A58 A63 A89 A94 A36 A42 A47 A59  ... A55 A62 A68 A5 A24 A27 A48  \
# A4    7   5   5   6   6   6   5   5   5   6  ...   1   1   1  1   1   1   1
# A35   5   7   6   5   5   5   6   3   6   5  ...   3   3   3  2   3   2   2
# A58   5   6   7   5   5   5   6   5   6   5  ...   1   2   2  1   2   1   2
# A63   6   5   5   7   7   6   5   5   5   7  ...   1   1   1  1   2   1   1
# A89   6   5   5   7   7   7   5   5   5   6  ...   1   1   1  3   1   2   1
# A94   6   5   5   6   7   7   5   5   5   6  ...   1   1   1  1   1   1   1
# A36   5   6   6   5   5   5   7   6   6   5  ...   1   1   1  2   1   2   1
# A42   5   3   5   5   5   5   6   7   5   5  ...   1   1   1  1   1   1   1
# A47   5   6   6   5   5   5   6   5   7   5  ...   1   1   1  1   1   1   1
# A59   6   5   5   7   6   6   5   5   5   7  ...   1   1   1  1   1   1   2
# A75   6   3   5   5   6   6   5   4   5   6  ...   2   1   2  1   1   1   1
# ...

# %%
merged_ratings[(merged_pairs['mov1'] == 'A68') & (merged_pairs['mov2'] == 'A13')]
# Out:
#       response        RT
# 1047         1  1.910931

# %%
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = pd.DataFrame(scaler.fit_transform(df), columns=df.columns, index=df.index)

plt.figure(figsize=(14, 12))
heatmap=sns.heatmap(df_scaled, cmap='coolwarm_r')
plt.show()

# %%
df = df.apply(pd.to_numeric, errors='coerce')

# %%
import matplotlib.patches as mpatches

plt.figure(figsize=(16, 14))
heatmap=sns.heatmap(df_scaled, cmap='coolwarm_r')
yticks = heatmap.get_yticklabels()
xticks = heatmap.get_xticklabels()
groups = [
    ('passive_inter', [4, 35, 58, 63, 89, 94]),
    ('active_inter', [36, 42, 47, 59, 75, 98]),
    ('comm_symbolic', [40, 51, 57]),
    ('comm_vocal', [2, 28, 85, 95]),
    ('manipulation', [7, 12, 13, 31, 50, 53, 96]),
    ('modify_substrate', [22, 44, 46, 64, 99]),
    ('digestion', [17, 21, 41, 72,88,92]),
    ('skin_displacement', [15, 16, 23, 70]),
    ('aim_in_space', [8, 20, 49, 71, 78, 87, 100]),
    ('locomotion_b', [55, 62, 68]),
    ('locomotion_q', [5,24,27,48,74, 77, 82])
]


colors = ['red', 'blue', 'green', 'purple', 'orange', 'brown', 'pink', 'gray', 'olive', 'cyan', 'magenta']

start = 0
for j,(group_name,indexes) in enumerate(groups):
    end = start + len(indexes)
    for i in range(start,end):
        yticks[i].set_color(colors[j])
        xticks[i].set_color(colors[j])
    start = end


heatmap.set_yticklabels(yticks)
patches = [mpatches.Patch(color=colors[i], label=name) for i,(name,indexes) in enumerate(groups)]
legend = plt.legend(handles=patches,bbox_to_anchor=(1.20,1), loc=2)
plt.setp(legend.get_texts(), fontsize='x-large') 

plt.show()

# %%
rounded_df = df_scaled.round(5)
dissimilarity_df = 1 - rounded_df
dissimilarity_df.to_csv(r'C:\Users\UmurY\OneDrive\Masaüstü\Action_Clusters_Python\Csvs\BehaviorSub1_rdm.csv')

# %%
test=pd.read_csv(r'C:\Program Files (x86)\Umram\ActionClusters Project\ActionClusters(mixed)\Experiment_Folder\Output\Umur\RDMs\brdm_sub1.csv',index_col=0)
test
# Out:
#            A4      A35      A58      A63      A89      A94      A36      A42  \
# A4    0.00000  0.33333  0.33333  0.16667  0.16667  0.16667  0.33333  0.33333
# A35   0.33333  0.00000  0.16667  0.33333  0.33333  0.33333  0.16667  0.66667
# A58   0.33333  0.16667  0.00000  0.33333  0.33333  0.33333  0.16667  0.33333
# A63   0.16667  0.33333  0.33333  0.00000  0.00000  0.16667  0.33333  0.33333
# A89   0.16667  0.33333  0.33333  0.00000  0.00000  0.00000  0.33333  0.33333
# A94   0.16667  0.33333  0.33333  0.16667  0.00000  0.00000  0.33333  0.33333
# A36   0.33333  0.16667  0.16667  0.33333  0.33333  0.33333  0.00000  0.16667
# A42   0.33333  0.66667  0.33333  0.33333  0.33333  0.33333  0.16667  0.00000
# A47   0.33333  0.16667  0.16667  0.33333  0.33333  0.33333  0.16667  0.33333
# A59   0.16667  0.33333  0.33333  0.00000  0.16667  0.16667  0.33333  0.33333
# A75   0.16667  0.66667  0.33333  0.33333  0.16667  0.16667  0.33333  0.50000
# ...
